# %% [markdown]
# ## 2. Data Generation
#
# Generate sequences from each component. Each sequence comes entirely from one component (non-ergodic). Label which component generated each sequence.

# %%
# TODO: Implement after reading papers

# %% [markdown]
# ## 1. Mess3 Hidden Markov Model
#
# A Mess3 process is a 3-state HMM parameterized by (alpha, x):
# - **alpha**: stickiness of hidden states (higher = stays longer in each state)
# - **x**: emission noise (lower = emissions are more informative about hidden state)
#
# We define multiple components with different parameters to create the non-ergodic dataset.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from scipy.stats import kendalltau
from sklearn.linear_model import Ridge
from sklearn.decomposition import PCA
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %%
# !pip install -q torch einops matplotlib numpy scipy scikit-learn

# %% [markdown]
# ## 0. Setup

# %% [markdown]
# # Non-Ergodic Mess3: Belief State Geometry with Multiple Components
#
# **Elena Ajayi**
#
# This notebook trains a small transformer on next-token prediction over sequences from multiple Mess3 processes (non-ergodic dataset), then extracts and analyzes belief state geometry from the residual stream.
